# %%
# Import libraries

import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

plt.style.use('ggplot')
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

# Now we need to read in the data
df = pd.read_csv('movies.csv')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# We need to see if we have any missing data
# Let's loop through the data and see if there is anything missing

for col in df.columns:
    print(col + ', ' + str(df[col].isnull().sum()))
# Out:
# name, 0
# rating, 12
# genre, 0
# year, 0
# released, 0
# score, 0
# votes, 0
# director, 0
# writer, 0
# star, 0
# country, 1
# budget, 0
# gross, 0
# company, 2
# runtime, 1

# %%
# Initial drop of rows with missing data
df.dropna()
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
# Check data types
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Remove rows with missing gross or budget values. We need values for correlations
df = df.dropna(subset=['gross', 'budget'])

# %%
# Adjust data types
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')

# %%
df.sort_values('gross', inplace=False, ascending=False)
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   387       5      0  2009       528    7.8  1100000.0       787    1265
# 7445   389       5      0  2019       138    8.4   903000.0       106     515
# 3045  4923       5      6  1997       535    7.8  1100000.0       787    1265
# 6663  3656       5      0  2015       530    7.8   876000.0       770    1810
# 7244   390       5      0  2018       146    8.4   897000.0       106     515
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 2434  2981       5      0  1993      1471    4.5     1900.0      1810    3112
# 3681  1599       3      6  2000      1726    6.8    43000.0       954    1687
# 272   2921       6      9  1982      1530    3.9     2300.0       263      55
# 2417  2401      -1      6  1993        64    7.3     5100.0        23    1220
# 3203  4980       5      4  1997      2158    5.7     5800.0       653     161
#
# ...

# %%
# Check for duplicates, checking for year too as movies are remade with the same name.
df[['name', 'year']].duplicated().value_counts()
# Out:
# False    5436
# dtype: int64

# %%
# Let's take a quick look at which movies ratings tend to earn the most money.
sns.stripplot(x="rating", y="gross", data=df, order=['Not Rated','G','PG','PG-13','R'])
plt.title("Gross Profit by Movie Rating")
plt.show()

# %%
# Scatterplot with budget vs gross
plt.scatter(x=df['budget'], y=df['gross'])

plt.title('Budget vs Gross Earnings')
plt.ylabel('Gross Earnings')
plt.xlabel('Budget')
plt.show()

# %%
# Regression plot with seaborn
sns.regplot(x='budget', y='gross', data=df, scatter_kws={'color':'teal'}, line_kws={'color':'blue'})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
# Looking a bit deeper at correlations between movie features
df.corr()
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.055174  0.205758  0.327781  0.274264  0.074203
# score    0.055174  1.000000  0.473809  0.071792  0.222143  0.414580
# votes    0.205758  0.473809  1.000000  0.440021  0.614904  0.352437
# budget   0.327781  0.071792  0.440021  1.000000  0.740395  0.318595
# gross    0.274264  0.222143  0.614904  0.740395  1.000000  0.275596
# runtime  0.074203  0.414580  0.352437  0.318595  0.275596  1.000000

# %%
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot=True)

plt.title('Correlation Matrix for Movie Features')
plt.show()

# %%
# Let's assign numerical values to categorical data for correlation comparisons

df_numerized = df.copy()

for col in df_numerized.columns:
    if (df_numerized[col].dtype == 'object'):
        df_numerized[col] = df_numerized[col].astype('category')
        df_numerized[col] = df_numerized[col].cat.codes

# %%
df_numerized.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  4706       6      6  1980      1308    8.4   927000.0      1800    2841
# 1  3943       6      1  1980      1131    5.8    65000.0      1581    1160
# 2  3654       4      0  1980      1363    8.7  1200000.0       759    1822
# 3   205       4      4  1980      1131    7.7   221000.0       891    1416
# 4   734       6      4  1980      1174    7.3   108000.0       721     352
#
#    star  country    budget      gross  company  runtime
# 0   700       46  19000000   46998772     1432    146.0
# 1   215       47   4500000   58853106      454    104.0
# 2  1161       47  18000000  538375067      949    124.0
# 3  1478       47   3500000   83453539     1114     88.0
# 4   272       47   6000000   39846344     1089     98.0

# %%
correlation_matrix = df_numerized.corr()

sns.heatmap(correlation_matrix, annot = True)
plt.title("Correlation matrix for Movies")
plt.xlabel("Movie features")
plt.ylabel("Movie features")
plt.show()

# %%
cor_pairs = df_numerized.corr().unstack()
cor_pairs.sort_values()
# Out:
# genre    budget    -0.368900
# budget   genre     -0.368900
# genre    gross     -0.244380
# gross    genre     -0.244380
# rating   budget    -0.186892
#                       ...
# year     year       1.000000
# genre    genre      1.000000
# rating   rating     1.000000
# company  company    1.000000
# runtime  runtime    1.000000
# Length: 225, dtype: float64

# %%
strong_pairs = cor_pairs[abs(cor_pairs) > 0.5]
pd.set_option('display.max_rows', None)
strong_pairs.sort_values()
# Out:
# gross     votes       0.614904
# votes     gross       0.614904
# gross     budget      0.740395
# budget    gross       0.740395
# name      name        1.000000
# gross     gross       1.000000
# budget    budget      1.000000
# country   country     1.000000
# star      star        1.000000
# writer    writer      1.000000
# director  director    1.000000
# votes     votes       1.000000
# score     score       1.000000
# released  released    1.000000
# year      year        1.000000
# genre     genre       1.000000
# rating    rating      1.000000
# company   company     1.000000
# runtime   runtime     1.000000
# dtype: float64

# %%
# We can tell that the only substantial correlations between movies features is between the movie budget/gross profits
# and gross profits/votes. This means that the more money spent to make a movie, the more it earns. The assumption then
# is that movies earn high profits because they are well liked, meaning a high correlation with profits and votes.
